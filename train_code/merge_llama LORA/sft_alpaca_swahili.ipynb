# %%
# import transformers

# # Get the version of the transformers library
# transformers_version = transformers.__version__
# transformers_version

# %%
# !pip install peft==0.3.0
# !pip install gguf
# !pip install pyarrow
# !!pip install sentencepiece
# Out:
# ['Collecting sentencepiece',
#  '  Downloading sentencepiece-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)',
#  'Downloading sentencepiece-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)',
#  '\x1b[?25l   \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b0.0/1.3 MB\x1b \x1b?\x1b eta \x1b-:--:--\x1b',
#  '\x1b[2K   \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b0.0/1.3 MB\x1b \x1b?\x1b eta \x1b-:--:--\x1b',
#  '\x1b[2K   \x1b╸\x1b\x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b0.0/1.3 MB\x1b \x1b731.7 kB/s\x1b eta \x1b0:00:02\x1b',
#  '\x1b[2K   \x1b╸\x1b\x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b0.0/1.3 MB\x1b \x1b731.7 kB/s\x1b eta \x1b0:00:02\x1b',
#  '\x1b[2K   \x1b━\x1b\x1b╸\x1b\x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b0.1/1.3 MB\x1b \x1b539.7 kB/s\x1b eta \x1b0:00:03\x1b',
# ...

# %%
# !python merge_llama_with_swahili_lora_low_mem.py \
    --base_model "/home/ai4d/Desktop/swahili_llama_pretrain/swahili_pretrained/llama_output" \
    --lora_model "/home/ai4d/Desktop/swahili_llama_pretrain/swahili_pretrained/UPDATED CHECKPOINT/pt_lora_model" \
    --output_type huggingface \
    --output_dir "/home/ai4d/Desktop/swahili_llama_pretrain/swahili_pretrained/OUTPUT_TRAINED_SWAHILI_LLaMA"
# Out:
# Base model: /home/ai4d/Desktop/swahili_llama_pretrain/swahili_pretrained/llama_output
# LoRA model(s) ['/home/ai4d/Desktop/swahili_llama_pretrain/swahili_pretrained/UPDATED CHECKPOINT/pt_lora_model']:
# Loading /home/ai4d/Desktop/swahili_llama_pretrain/swahili_pretrained/UPDATED CHECKPOINT/pt_lora_model
# Loading ckpt pytorch_model-00001-of-00003.bin
# Merging...
# Saving ckpt pytorch_model-00001-of-00003.bin to /home/ai4d/Desktop/swahili_llama_pretrain/swahili_pretrained/OUTPUT_TRAINED_SWAHILI_LLaMA in HF format...
# Loading ckpt pytorch_model-00002-of-00003.bin
# Merging...
# Saving ckpt pytorch_model-00002-of-00003.bin to /home/ai4d/Desktop/swahili_llama_pretrain/swahili_pretrained/OUTPUT_TRAINED_SWAHILI_LLaMA in HF format...
# Loading ckpt pytorch_model-00003-of-00003.bin
# Merging...
# Saving ckpt pytorch_model-00003-of-00003.bin to /home/ai4d/Desktop/swahili_llama_pretrain/swahili_pretrained/OUTPUT_TRAINED_SWAHILI_LLaMA in HF format...
# Saving tokenizer
# Saving config.json
# ...

# %%
# !pwd
# Out:
# /home/ai4d/Desktop/swahili_llama_pretrain/kaggle_like_sft
